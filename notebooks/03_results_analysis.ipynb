# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from src.test import test_main
# Out:
# 2025-12-06 02:32:21.223398: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-06 02:32:21.223645: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-06 02:32:21.314129: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
test_main()
# Out:
# Changing working directory to /home/atg/LearnCoding/Projects/Data Science/Projects/Banana-Prediction-CNN/src to support data loading...
# Loading data...
# Found 11793 images belonging to 4 classes.
# Found 1123 images belonging to 4 classes.
# Found 562 images belonging to 4 classes.
# Loading model from /home/atg/LearnCoding/Projects/Data Science/Projects/Banana-Prediction-CNN/models/banana_model_best.keras...
# 2025-12-06 02:32:41.547282: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...
# Evaluating on Train Data...
# ...
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 91s 245ms/step - accuracy: 0.9483 - loss: 0.1429
# Train Loss: 0.1429
# Train Accuracy: 0.9483
#
# ...
# Evaluating on Validation Data...
# ...
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9644 - loss: 0.1257
# Validation Loss: 0.1257
# Validation Accuracy: 0.9644
#
# ...
# Evaluating on Test Data...
# ...
