# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

import matplotlib.pyplot as plt
import numpy as np
from src.data_processing import load_data
# Out:
# 2025-12-06 01:22:47.291152: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-06 01:22:47.291579: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-06 01:22:47.388687: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-06 01:22:50.623729: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-06 01:22:50.624053: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ### Data Exploration

# %%
train_gen, val_gen, test_gen = load_data()
print("Classes:", train_gen.class_indices)
print("Train samples:", train_gen.samples)
print("Val samples:", val_gen.samples)
# Out:
# Found 11793 images belonging to 4 classes.
# Found 1123 images belonging to 4 classes.
# Found 562 images belonging to 4 classes.
# Classes: {'overripe': 0, 'ripe': 1, 'rotten': 2, 'unripe': 3}
# Train samples: 11793
# Val samples: 1123

# %%
images, labels = next(train_gen)
plt.figure(figsize=(12, 8))

class_names = {0: 'overripe', 1: 'ripe', 2: 'rotten', 3: 'unripe'}

for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(images[i])
    class_idx = np.argmax(labels[i])
    plt.title(f'Class: {class_names[class_idx]}')
    plt.axis('off')
plt.tight_layout()
plt.show();
